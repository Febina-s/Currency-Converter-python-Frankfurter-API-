# %% [markdown]
# ## Pulling data from Public API'S-GET REQUEST

# %%
base_url = "https://api.frankfurter.dev/v1/latest"

# %% [markdown]
# ### sending request

# %%
import requests
response=requests.get(base_url)

# %%
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"amount":1.0,"base":"EUR","date":"2025-12-09","rates":{"AUD":1.7532,"BGN":1.9558,"BRL":6.3588,"CAD":1.6114,"CHF":0.9385,"CNY":8.2207,"CZK":24.277,"DKK":7.4689,"GBP":0.8735,"HKD":9.056,"HUF":383.85,"IDR":19403,"ILS":3.7395,"INR":104.55,"ISK":148.8,"JPY":181.96,"KRW":1708.91,"MXN":21.269,"MYR":4.7886,"NOK":11.7845,"NZD":2.0111,"PHP":69.043,"PLN":4.2303,"RON":5.0897,"SEK":10.9015,"SGD":1.5091,"THB":37.07,"TRY":49.554,"USD":1.1637,"ZAR":19.8661}}'

# %% [markdown]
# #### Handling JSON

# %%
response.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
import json

# %%
print(json.dumps(response.json(),indent=4))
# Out:
# {
#     "amount": 1.0,
#     "base": "EUR",
#     "date": "2025-12-09",
#     "rates": {
#         "AUD": 1.7532,
#         "BGN": 1.9558,
#         "BRL": 6.3588,
#         "CAD": 1.6114,
#         "CHF": 0.9385,
#         "CNY": 8.2207,
#         "CZK": 24.277,
#         "DKK": 7.4689,
#         "GBP": 0.8735,
#         "HKD": 9.056,
#         "HUF": 383.85,
#         "IDR": 19403,
#         "ILS": 3.7395,
#         "INR": 104.55,
#         "ISK": 148.8,
#         "JPY": 181.96,
#         "KRW": 1708.91,
#         "MXN": 21.269,
#         "MYR": 4.7886,
#         "NOK": 11.7845,
#         "NZD": 2.0111,
#         "PHP": 69.043,
#         "PLN": 4.2303,
#         "RON": 5.0897,
#         "SEK": 10.9015,
#         "SGD": 1.5091,
#         "THB": 37.07,
#         "TRY": 49.554,
#         "USD": 1.1637,
#         "ZAR": 19.8661
#     }
# }

# %% [markdown]
# #### obtaining hostorical url

# %%
base_url = "https://api.frankfurter.dev/v1"

# %%
historical_url=base_url+ "/2025-06-17"
historical_url
# Out:
# 'https://api.frankfurter.dev/v1/2025-06-17'

# %%
response = requests.get(historical_url)
response.status_code
# Out:
# 200

# %%
data = response.json()
print(json.dumps(data, indent=4))
# Out:
# {
#     "amount": 1.0,
#     "base": "EUR",
#     "date": "2025-06-17",
#     "rates": {
#         "AUD": 1.7693,
#         "BGN": 1.9558,
#         "BRL": 6.347,
#         "CAD": 1.5688,
#         "CHF": 0.9406,
#         "CNY": 8.3091,
#         "CZK": 24.8,
#         "DKK": 7.4585,
#         "GBP": 0.8525,
#         "HKD": 9.0805,
#         "HUF": 402.83,
#         "IDR": 18852,
#         "ILS": 4.0509,
#         "INR": 99.78,
#         "ISK": 143.6,
#         "JPY": 167.35,
#         "KRW": 1579.42,
#         "MXN": 21.896,
#         "MYR": 4.9112,
#         "NOK": 11.4175,
#         "NZD": 1.904,
#         "PHP": 65.143,
#         "PLN": 4.2778,
#         "RON": 5.028,
#         "SEK": 10.948,
#         "SGD": 1.4817,
#         "THB": 37.613,
#         "TRY": 45.561,
#         "USD": 1.1568,
#         "ZAR": 20.611
#     }
# }

# %%
currencies_list_url = base_url + "/currencies"
currencies_list_url
# Out:
# 'https://api.frankfurter.dev/v1/currencies'

# %%
response = requests.get(currencies_list_url)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'AUD': 'Australian Dollar',
#  'BGN': 'Bulgarian Lev',
#  'BRL': 'Brazilian Real',
#  'CAD': 'Canadian Dollar',
#  'CHF': 'Swiss Franc',
#  'CNY': 'Chinese Renminbi Yuan',
#  'CZK': 'Czech Koruna',
#  'DKK': 'Danish Krone',
#  'EUR': 'Euro',
#  'GBP': 'British Pound',
#  'HKD': 'Hong Kong Dollar',
#  'HUF': 'Hungarian Forint',
#  'IDR': 'Indonesian Rupiah',
#  'ILS': 'Israeli New Sheqel',
#  'INR': 'Indian Rupee',
#  'ISK': 'Icelandic Króna',
#  'JPY': 'Japanese Yen',
#  'KRW': 'South Korean Won',
#  'MXN': 'Mexican Peso',
#  'MYR': 'Malaysian Ringgit',
#  'NOK': 'Norwegian Krone',
#  'NZD': 'New Zealand Dollar',
#  'PHP': 'Philippine Peso',
#  'PLN': 'Polish Złoty',
#  'RON': 'Romanian Leu',
#  'SEK': 'Swedish Krona',
#  'SGD': 'Singapore Dollar',
#  'THB': 'Thai Baht',
#  'TRY': 'Turkish Lira',
#  'USD': 'United States Dollar',
#  'ZAR': 'South African Rand'}

# %% [markdown]
# ## Currency converter

# %%
date = input("Please enter the date (in the format 'yyyy-mm-dd'), or type 'latest' if you are interested in the data for \
the most recent available date'):")
base = input("Convert from (currency): ")
curr = input ("Convert to (currency): ")
amt = float(input("How much {} would you like to convert?: ".format(base)))

url = base_url + "/" + date + "?base=" + base + "&symbols=" + curr
response = requests.get(url)

if(response.ok is False):
    print("\nError {}:".format()(response.status_code))
    print(response.json()['error'])

else:
    data = response.json()
    rate = data['rates'][curr]

    result = amt*rate

    print("\n{0}{1} was equal to {2}{3}, based on the exchange rate on {4}".format(base, amt, curr, result, data['date']))
# Out:
# USD40.0 was equal to INR3593.6000000000004, based on the exchange rate on 2025-12-09
